# %%
# !pip install scikit-learn
# !pip install numpy
# Out:
# Requirement already satisfied: scikit-learn in c:\users\abdirahman\desktop\ml_project\knn-project\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\abdirahman\desktop\ml_project\knn-project\.venv\lib\site-packages (from scikit-learn) (2.3.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\abdirahman\desktop\ml_project\knn-project\.venv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\abdirahman\desktop\ml_project\knn-project\.venv\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\abdirahman\desktop\ml_project\knn-project\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\abdirahman\desktop\ml_project\knn-project\.venv\lib\site-packages (2.3.4)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# Dataset
X = np.array([[2,4],[1,3],[4,6],[5,7],[3,5]])
y = np.array([0,0,1,1,1])  # 0 = Fail, 1 = Pass

# Model
model = RandomForestClassifier(n_estimators=10)  # 10 trees

# Train
model.fit(X, y)

# Predict
new_student = [[3,4]]
prediction = model.predict(new_student)

print("Prediction:", prediction)
# Out:
# Prediction: [0]
